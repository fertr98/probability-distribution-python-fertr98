# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return resultk

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial.
import numpy as np
np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %% [markdown]
# NORMAL DISTRIBUTION

# %%
# TODO

from scipy.stats import norm

def dnorm(d, mean, std):
    """
    Calculates the probability of density:
    """
    result = norm.pdf(x = d, loc = mean, scale = std)

    return result

def pnorm(p, mean, std):
    """
    Calculates the probability of cumulative distribution:
    """
    result = norm.cdf(x = p, loc = mean, scale = std)

    return result

def qnorm(q, mean, std):
    """
    Calculates the percentile function from the normal distribution:
    """
    result = norm.ppf(q, loc = mean, scale = std)

    return result

def rnorm(x, mean, std, n):
    """
    Generates random variables from the normal distribution:
    """
    result = norm.rvs(loc = mean, scale = std, size = n, random_state = None)

    return result

# %%
import numpy as np
np.random.seed(8)

print(f"probability of density distribution: {dnorm(8, 20, 1)}")
print(f"probability of cumulative distribution: {pnorm(8, 20, 1)}")
print(f"percentile function from the normal distribution: {qnorm(0.9, 10, 0.2)}")
print(f"random variables from the normal distribution: {rnorm( 20, 1, 100, None)} ")
# Out:
# probability of density distribution: 2.1463837356630605e-32
# probability of cumulative distribution: 1.776482112077653e-33
# percentile function from the normal distribution: 10.25631031310892
# random variables from the normal distribution: 10.120471661981977

# %%
import matplotlib.pyplot as plt
np.random.seed(8)


mean = 10
std = 5
data = np.arange(-20, 20, 0.1)

pdf = dnorm(data, mean, std)
cdf = pnorm(data, mean, std)
ppf = qnorm(data, mean, std)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].plot(data, pdf, "r-")
axis[1].plot(data, cdf, "b-")
axis[2].plot(ppf, data, "g-")

plt.tight_layout()

plt.show()
# Out:
# 400
# 400

# %%
# TODO

from scipy.stats import uniform

def duni(d, mean, std):
    """
    Calculates the probability of density:
    """
    result = uniform.pdf(x = d, loc = mean, scale = std)

    return result

def puni(p, mean, std):
    """
    Calculates the probability of cumulative distribution:
    """
    result = uniform.cdf(x = p, loc = mean, scale = std)

    return result

def quni(q, mean, std):
    """
    Calculates the percentile function from the normal distribution:
    """
    result = uniform.ppf(q, loc = mean, scale = std)

    return result

def runi(x, mean, std, n):
    """
    Generates random variables from the normal distribution:
    """
    result = uniform.rvs(loc = mean, scale = std, size = n, random_state = None)

    return result

# %%
import numpy as np
np.random.seed(8)

print(f"probability of density distribution: {duni(8, 20, 1)}")
print(f"probability of cumulative distribution: {puni(8, 20, 1)}")
print(f"percentile function from the normal distribution: {quni(0.9, 10, 0.2)}")
print(f"random variables from the normal distribution: {runi( 20, 1, 100, None)} ")
# Out:
# probability of density distribution: 0.0
# probability of cumulative distribution: 0.0
# percentile function from the normal distribution: 10.18
# random variables from the normal distribution: 88.34294027918162

# %%
import matplotlib.pyplot as plt
np.random.seed(8)


mean = 10
std = 5
data = np.arange(-20, 20, 0.1)

pdf = duni(data, mean, std)
cdf = puni(data, mean, std)
ppf = quni(data, mean, std)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].plot(data, pdf, "r-")
axis[1].plot(data, cdf, "b-")
axis[2].plot(ppf, data, "g-")

plt.tight_layout()

plt.show()
